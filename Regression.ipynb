# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns ### importing seaborn
import pandas as pd
import scipy.stats as ss

# %%
import statsmodels.api as sm

wages_data = sm.datasets.get_rdataset("Wages", "plm")
df_wages = wages_data.data
print(df_wages.head())
# Out:
#    exp  wks bluecol  ind south smsa married   sex union  ed black    lwage
# 0    3   32      no    0   yes   no     yes  male    no   9    no  5.56068
# 1    4   43      no    0   yes   no     yes  male    no   9    no  5.72031
# 2    5   40      no    0   yes   no     yes  male    no   9    no  5.99645
# 3    6   39      no    0   yes   no     yes  male    no   9    no  5.99645
# 4    7   42      no    1   yes   no     yes  male    no   9    no  6.06146

# %%
corr_matrix = df_wages.iloc[:, :].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# making a simple model to turn into a multidimensional model next week
#
# lwage = b0 + b1 * educ
# log y = b0 + b1x1
# y = exp(b0 + b1x1)

# %%
sns.scatterplot(data = df_wages, y='lwage', x='ed');
sns.regplot(data = df_wages, y='lwage', x='ed');
# find coefficients of the line
# 1. find minimum of the function through derivatives

# INSTALL STATSMODELS - here it's already installed

# %%
# model 1. simple model for LWAGE vs EXPERIENCE
import statsmodels.formula.api as smf
results = smf.ols('lwage ~ed', data=df_wages).fit()
print(results.summary)
# print a table of sorts .. ? i couldn't rewrite the code in time :(

# lwage = intercept 5.83 + ed 0.065 * educ
# lwage = log of wages btw
# Out:
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x000001AC36F1F7F0>>

# %%
# old regression results
